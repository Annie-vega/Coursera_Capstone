# %% [markdown]
# # Welcome to my capstone project
# #### By Annie Vega

# %% [markdown]
# I'll start the project by setting up my environment, installing all that I need and keep going

# %%
#Make sure all the pip are installed in the terminal
#pip install jupyter
#pip install lxml

# specify which URL/web page we are going to be scraping
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %% [markdown]
# ### I'm reading the table from Wikipedia using the function read_html, since the Neighbourhood table is the first one, we just call the table 0

# %%
table_CA = pd.read_html(url)
df = table_CA[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# Ignore cells with a borough that is Not assigned

# %%
# get names of indexes for which column Borough has value "Not assigned" 
borough = df[ df['Borough'] == 'Not assigned' ].index 
  
# drop these row indexes from dataFrame 
df.drop(borough, inplace = True) 
  
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# ### If a cell has a borough but a Not assigned  neighborhood, then the neighborhood will be the same as the borough.
# ### To prove if there's any Neighbourhood defined as "Not assigned", if all the values are

# %%
(df['Neighbourhood'] == 'Not assigned').sum()
# Out:
# 0

# %%
df.shape
# Out:
# (103, 3)

# %%
#Geospatial coordinates
filename = "https://cocl.us/Geospatial_data"
df1 = pd.read_csv(filename)
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df1.shape
# Out:
# (103, 3)

# %%
df1.sort_values('Postal Code')
df1.tail()
# Out:
#     Postal Code   Latitude  Longitude
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054

# %%
df2 = df1.drop(['Postal Code'], axis = 1) 
df2
# Out:
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.763573 -79.188711
# 3    43.770992 -79.216917
# 4    43.773136 -79.239476
# ..         ...        ...
# 98   43.706876 -79.518188
# 99   43.696319 -79.532242
# 100  43.688905 -79.554724
# 101  43.739416 -79.588437
# 102  43.706748 -79.594054
#
# [103 rows x 2 columns]

# %%
df.sort_values('Postal Code')
df.tail()
# Out:
#     Postal Code           Borough  \
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...

# %% [markdown]
# ### Concatenate the data frames and include the postal codes

# %%
frames = [df, df2] 

result = pd.concat([df2, df], axis=1, join='outer') 
display(result)
# Out:
#       Latitude  Longitude Postal Code           Borough  \
# 0    43.806686 -79.194353         NaN               NaN
# 1    43.784535 -79.160497         NaN               NaN
# 2    43.763573 -79.188711         M3A        North York
# 3    43.770992 -79.216917         M4A        North York
# 4    43.773136 -79.239476         M5A  Downtown Toronto
# ..         ...        ...         ...               ...
# 160        NaN        NaN         M8X         Etobicoke
# 165        NaN        NaN         M4Y  Downtown Toronto
# 168        NaN        NaN         M7Y      East Toronto
# 169        NaN        NaN         M8Y         Etobicoke
# 178        NaN        NaN         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [138 rows x 5 columns]

# %%
# get names of indexes for which column Borough has value "Not assigned" 
result = result.dropna() 

result
# Out:
#       Latitude  Longitude Postal Code           Borough  \
# 2    43.763573 -79.188711         M3A        North York
# 3    43.770992 -79.216917         M4A        North York
# 4    43.773136 -79.239476         M5A  Downtown Toronto
# 5    43.744734 -79.239476         M6A        North York
# 6    43.727929 -79.262029         M7A  Downtown Toronto
# ..         ...        ...         ...               ...
# 95   43.643515 -79.577201         M6N              York
# 98   43.706876 -79.518188         M9N              York
# 99   43.696319 -79.532242         M1P       Scarborough
# 100  43.688905 -79.554724         M2P        North York
# 102  43.706748 -79.594054         M4P   Central Toronto
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 95                       Runnymede, The Junction North
# 98                                              Weston
# 99   Dorset Park, Wexford Heights, Scarborough Town...
# 100                                    York Mills West
# 102                                   Davisville North
#
# [68 rows x 5 columns]

# %%
#Reorganize columns
result1=result.reindex(columns= ['Postal Code', 'Borough', 'Neighbourhood','Latitude','Longitude'])
result1
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 95          M6N              York
# 98          M9N              York
# 99          M1P       Scarborough
# 100         M2P        North York
# 102         M4P   Central Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 2                                            Parkwoods  43.763573 -79.188711
# 3                                     Victoria Village  43.770992 -79.216917
# 4                            Regent Park, Harbourfront  43.773136 -79.239476
# 5                     Lawrence Manor, Lawrence Heights  43.744734 -79.239476
# 6          Queen's Park, Ontario Provincial Government  43.727929 -79.262029
# ..                                                 ...        ...        ...
# 95                       Runnymede, The Junction North  43.643515 -79.577201
# 98                                              Weston  43.706876 -79.518188
# 99   Dorset Park, Wexford Heights, Scarborough Town...  43.696319 -79.532242
# 100                                    York Mills West  43.688905 -79.554724
# 102                                   Davisville North  43.706748 -79.594054
#
# [68 rows x 5 columns]
